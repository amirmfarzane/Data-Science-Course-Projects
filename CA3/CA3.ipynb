# %%
from pyspark.sql import SparkSession

# Get existed or Create new SparkSession
spark = SparkSession.builder.appName('Spark Demo').master('local[*]').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-MSJ4V9T:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark Demo</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import functions as F

# %% [markdown]
# # Warm-Up!

# %% [markdown]
# ## Q1

# %%
data_path = 'stocks.csv'
df = spark.read.csv(data_path, header=True, inferSchema=True)

# %% [markdown]
# ## Q2

# %%
df.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: double (nullable = true)

# %% [markdown]
# ## Q3

# %%
df.where(df['Close']<500).select(df.Open, df.Close, df.Volume).show(10)
# Out:
# +------------------+------------------+---------+
# |              Open|             Close|   Volume|
# +------------------+------------------+---------+
# |        213.429998|        214.009998|123432400|
# |        214.599998|        214.379993|150476200|
# |        214.379993|        210.969995|138040000|
# |            211.75|            210.58|119282800|
# |        210.299994|211.98000499999998|111902700|
# |212.79999700000002|210.11000299999998|115557400|
# |209.18999499999998|        207.720001|148614900|
# |        207.870005|        210.650002|151473000|
# |210.11000299999998|            209.43|108223500|
# |210.92999500000002|            205.93|148516900|
# +------------------+------------------+---------+
# only showing top 10 rows

# %% [markdown]
# ## Q4

# %%
df.where((F.col('Close')<200) & (F.col('Open') > 200)).show(10)
# Out:
# +----------+------------------+----------+----------+----------+---------+------------------+
# |      Date|              Open|      High|       Low|     Close|   Volume|         Adj Close|
# +----------+------------------+----------+----------+----------+---------+------------------+
# |2010-01-22|206.78000600000001|207.499996|    197.16|    197.75|220441900|         25.620401|
# |2010-01-28|        204.930004|205.500004|198.699995|199.289995|293375600|25.819922000000002|
# |2010-01-29|        201.079996|202.199995|190.250002|192.060003|311488100|         24.883208|
# +----------+------------------+----------+----------+----------+---------+------------------+

# %% [markdown]
# ## Q5

# %%
df2 = df.withColumn('Year',F.year(F.to_timestamp('Date', 'dd/MM/yyyy')))

# %%
df2.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|Year|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|2010|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|2010|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|2010|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|2010|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|2010|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|2010|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|2010|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|2010|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|2010|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|2010|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|2010|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|2010|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|2010|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|2010|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|2010|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|2010|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Q6

# %%
df4.groupBy('Year').agg(F.min('Volume').alias('minVolume')).show()
# Out:
# +----+---------+
# |Year|minVolume|
# +----+---------+
# |2015| 13046400|
# |2013| 41888700|
# |2014| 14479600|
# |2012| 43938300|
# |2016| 11475900|
# |2010| 39373600|
# |2011| 44915500|
# +----+---------+

# %% [markdown]
# ## Q7

# %%
df3 = df2.withColumn('Month',F.month(F.to_timestamp('Date', 'dd/MM/yyyy')))

# %%
df3.show(10)
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|Year|Month|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010|    1|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010|    1|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010|    1|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|2010|    1|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010|    1|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|2010|    1|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|2010|    1|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|2010|    1|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|2010|    1|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|2010|    1|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+
# only showing top 10 rows

# %%
df4 = df3.withColumn('Year/Month',F.concat('Year', f.lit("/"), 'Month'))

# %%
df4.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+----------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|Year|Month|Year/Month|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+----------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010|    1|    2010/1|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010|    1|    2010/1|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010|    1|    2010/1|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|2010|    1|    2010/1|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010|    1|    2010/1|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|2010|    1|    2010/1|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|2010|    1|    2010/1|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|2010|    1|    2010/1|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|2010|    1|    2010/1|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|2010|    1|    2010/1|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|2010|    1|    2010/1|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|2010|    1|    2010/1|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|2010|    1|    2010/1|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|2010|    1|    2010/1|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|2010|    1|    2010/1|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|2010|    1|    2010/1|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|2010|    1|    2010/1|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|2010|    1|    2010/1|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|2010|    1|    2010/1|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|2010|    2|    2010/2|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+----------+
# only showing top 20 rows

# %%
df4.groupBy('Year/Month').agg(F.max('Low').alias('maxLow')).show()
# Out:
# +----------+------------------+
# |Year/Month|            maxLow|
# +----------+------------------+
# |    2013/6|447.38999900000005|
# |    2011/9|        412.000004|
# |    2014/8|        102.199997|
# |    2016/4|111.33000200000001|
# |    2010/2|        202.000004|
# |   2015/11|        121.620003|
# |   2012/11|        594.170021|
# |    2012/4| 626.0000150000001|
# |    2014/6|        644.470024|
# |    2010/1|        213.249994|
# |    2011/2|             360.5|
# |    2014/2| 545.6099780000001|
# |    2011/1|        344.440006|
# |    2010/5|        262.880009|
# |   2011/12|        403.490009|
# |   2013/11|        547.809975|
# |   2011/11|        401.560005|
# |    2015/2|        131.169998|
# |   2014/12|        115.290001|
# |   2010/10|        314.289997|
# +----------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Q8

# %%
df.agg(F.round(F.mean('High'), 2).alias('Avg'), F.round(F.std('High'), 2).alias('Std')).show()
# Out:
# +------+-----+
# |   Avg|  Std|
# +------+-----+
# |315.91|186.9|
# +------+-----+
